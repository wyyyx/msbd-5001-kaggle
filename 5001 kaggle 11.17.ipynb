# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
TrainData = pd.read_csv("5001train.csv")
TestData  = pd.read_csv("5001test.csv")
import seaborn as sb ##includes convenient heatmaps and boxplots
import sklearn.linear_model as sklm ##Includes Logistic Regression, which will be tested for predictive capability
import sklearn.decomposition as skdc ##Includes Principal Component Analysis, a method of dimensionality reduction
import sklearn.pipeline as skpl ##Convenient module for calculating PCs and using them in logistic regression
# %matplotlib inline
from subprocess import check_output
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from pandas.core.frame import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#result=[]
#for i in  range(0, 400):
    X1,Y1=make_classification(n_samples = TrainData.iat[i,7], n_features= TrainData.iat[i,8] , n_classes = TrainData.iat[i,9]  , n_clusters_per_class = TrainData.iat[i,10] ,n_informative = TrainData.iat[i,11], flip_y= TrainData.iat[i,12] , scale= TrainData.iat[i,13])
    import time
    from sklearn.linear_model import SGDClassifier
    clf = SGDClassifier(penalty = TrainData.iat[i,1], l1_ratio = TrainData.iat[i,2], alpha = TrainData.iat[i,3], max_iter = TrainData.iat[i,4], random_state = TrainData.iat[i,5], n_jobs = TrainData.iat[i,6])
    start = time.time()  
    clf.fit(X1, Y1)
    elapsed = (time.time() - start)
    result.append(elapsed)
    #print(elapsed)    
print(i,result)
# Out:
#   File "<ipython-input-2-b1c52d638022>", line 3
#     X1,Y1=make_classification(n_samples = TrainData.iat[i,7], n_features= TrainData.iat[i,8] , n_classes = TrainData.iat[i,9]  , n_clusters_per_class = TrainData.iat[i,10] ,n_informative = TrainData.iat[i,11], flip_y= TrainData.iat[i,12] , scale= TrainData.iat[i,13])
#     ^
# IndentationError: unexpected indent

# %%
#result3= [0.6151981353759766, 3.403468132019043, 0.44011378288269043, 1.223059892654419, 0.6190097332000732, 14.593369722366333, 2.8760578632354736, 5.941915035247803, 0.9744052886962891, 3.7875490188598633, 3.1714141368865967, 1.3377199172973633, 0.821415901184082, 3.124998092651367, 1.7463250160217285, 0.10274410247802734, 1.719857931137085, 0.5167500972747803, 1.7572379112243652, 5.337353944778442, 0.10609292984008789, 0.6158859729766846, 0.7237441539764404, 0.9295642375946045, 2.794394016265869, 0.5917298793792725, 2.367151975631714, 0.31098389625549316, 0.9205741882324219, 3.2072768211364746, 2.442456007003784, 0.7241332530975342, 0.3112938404083252, 6.125020980834961, 0.8213889598846436, 2.5600149631500244, 6.491910219192505, 0.304671049118042, 22.718006134033203, 0.10198187828063965, 14.421616077423096, 4.505017280578613, 0.82523512840271, 0.4192171096801758, 0.8306899070739746, 2.5729739665985107, 5.257785081863403, 12.294674158096313, 19.528871059417725, 0.10575699806213379, 5.527554988861084, 1.6282272338867188, 5.887305021286011, 0.9032771587371826, 0.7163269519805908, 9.812453031539917, 3.1692798137664795, 0.819782018661499, 4.925498962402344, 0.931776762008667, 2.854435920715332, 0.8418598175048828, 1.9513001441955566, 1.3411602973937988, 2.604151964187622, 0.7200808525085449, 4.3775529861450195, 0.4111049175262451, 1.0366199016571045, 0.3527648448944092, 1.021394968032837, 0.30917906761169434, 11.656479120254
 0.20891189575195312, 0.10697507858276367, 0.17975807189941406, 0.4140489101409912, 0.41350293159484863, 0.10671091079711914, 1.289747953414917, 0.10696697235107422, 2.876093864440918, 34.18472909927368, 0.31520986557006836, 0.6289060115814209, 3.8123199939727783, 36.322672843933105, 5.1749267578125, 0.4716610908508301, 0.20706701278686523, 0.7836551666259766, 1.1445951461791992, 8.767911911010742, 17.4808189868927, 0.529865026473999, 2.022545337677002, 385.8222279548645, 7.5276780128479, 1.1668989658355713, 1.0193941593170166, 3.9484221935272217, 2.4435060024261475, 5.282494783401489, 4.89394998550415, 1.5908007621765137, 3.686781167984009, 0.5841927528381348, 3.6481127738952637, 0.29803991317749023, 3.774254083633423, 1.0513761043548584, 0.5379900932312012, 1.3046650886535645, 0.32418394088745117, 0.546309232711792, 1.3494091033935547, 0.21825313568115234, 328.46516036987305, 3.39949893951416, 6.867437839508057, 4.251291036605835, 5.65966010093689, 15.177632570266724, 4.143943786621094, 0.21849799156188965, 0.7494468688964844, 0.3367919921875, 1011.4473369121552, 0.4202408790588379, 0.42536497116088867, 1.7943699359893799, 0.3888721466064453, 5.212893009185791, 0.4348268508911133, 2.6381471157073975, 4.020766019821167, 0.21977496147155762, 7.307394027709961, 0.11048316955566406, 2.5384769439697266, 1.65024995803833, 1.2673051357269287, 4.642539024353027, 2.342099905014038, 2.0134899616241455, 0.2686278820037842]
pd.set_option('display.max_rows', None)
f=pd.DataFrame({"id":TrainData['id'], "time":TrainData['time'],"time_pred":list(result)})
f
# Out:
#       id       time  time_pred
# 0      0   0.409987   0.610678
# 1      1   3.950953   3.152955
# 2      2   0.368702   0.409819
# 3      3   1.004559   1.129069
# 4      4   0.802800   0.613363
# 5      5   7.916113  13.576040
# 6      6   2.206062   2.966572
# 7      7   2.407143   5.718677
# 8      8   1.002341   1.031603
# 9      9   1.607144   3.909572
# 10    10   0.905699   2.566679
# 11    11   1.003842   1.220267
# 12    12   0.803387   0.814769
# 13    13   1.207392   2.785466
# 14    14   1.507312   1.850187
# 15    15   0.101734   0.105431
# 16    16   1.564080   2.067579
# 17    17   0.603312   0.519832
# 18    18   1.405601   1.625514
# 19    19   6.013842   7.038925
# 20    20   0.104154   0.103014
# 21    21   0.504131   0.613041
# 22    22   0.603173   0.914411
# 23    23   0.308614   1.123406
# 24    24   3.107064   3.796450
# 25    25   0.542533   0.645894
# 26    26   3.107124   2.851172
# 27    27   0.302663   0.510017
# 28    28   0.307453   1.129783
# ...

# %%
#X =np.array(f.time).reshape(-1,1)
#X

# %%
#from sklearn import linear_model
#clf = linear_model.LinearRegression()
#X =np.array(f.time).reshape(-1,1)
#y = f.time_pred
#clf.fit(X,y)
#print(clf.coef_)
#print(clf.intercept_)

# %%
TrainData2 = TrainData1[['l1_ratio' , 'alpha' , 'max_iter' , 'n_jobs' , 'n_samples' , 'n_features' , 'n_classes' , 'n_clusters_per_class'  , 'flip_y' , 'scale', 'time_pre', 'penalty_elasticnet', 'penalty_l1','penalty_l2','penalty_none']]

# %%
n_samplefeature = TrainData2.n_samples*TrainData2.n_features
TrainData2['nsamplefeature'] =n_samplefeature
TrainData2.drop('n_samples',axis=1, inplace=True)
TrainData2.drop('n_features',axis=1, inplace=True)
n_classes1 = TrainData2.n_classes*TrainData2.n_clusters_per_class
TrainData2['n_classes1'] =n_classes1
TrainData2.drop('n_classes',axis=1, inplace=True)
TrainData2.drop('n_clusters_per_class',axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import numpy as np
x = TrainData2['max_iter']
TrainData2['max_iter'] = (x - np.mean(x) )/np.std(x, ddof = 1)
x1 = TrainData2['nsamplefeature']
TrainData2['nsamplefeature'] = (x1 - np.mean(x1) )/np.std(x1, ddof = 1)
x1 = TrainData2['n_classes1']
TrainData2['n_classes1'] = (x1 - np.mean(x1) )/np.std(x1, ddof = 1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#n_sampley0 = TrainData2.n_samples*TrainData2.flip_y
#n_sampley   = TrainData2.n_samples - n_sampley0
#TrainData2['nsampley'] =n_sampley
#TrainData2.drop('flip_y',axis=1, inplace=True)
#n_samplefeature = TrainData2.n_samples*TrainData2.n_features
#TrainData2.drop('n_samples',axis=1, inplace=True)
#TrainData2.drop('n_features',axis=1, inplace=True)

# %%
#TrainData2.drop('flip_y',axis=1, inplace=True)
#TrainData2.drop('n_samples',axis=1, inplace=True)
#TrainData2.drop('n_features',axis=1, inplace=True)
#TrainData2.drop('scale',axis=1, inplace=True)
#TrainData2.drop('l1_ratio',axis=1, inplace=True)
#TrainData2.drop('max_iter',axis=1, inplace=True)
#TrainData2.drop('alpha',axis=1, inplace=True)
#TrainData2.drop('n_classes',axis=1, inplace=True)
#TrainData2.drop('n_clusters_per_class',axis=1, inplace=True)

# %%
TrainData2
# Out:
#      l1_ratio   alpha  max_iter  n_jobs    flip_y      scale   time_pre  \
# 0    0.304083  0.0001 -0.522679      -1  0.074798  24.242009   0.610678
# 1    0.727744  0.0010  0.084868       1  0.077781  54.626302   3.152955
# 2    0.745885  0.0100  0.122604       2  0.030196  17.999964   0.409819
# 3    0.474605  0.0010  1.032038       4  0.057261  82.257222   1.129069
# 4    0.395049  0.0010 -1.466075       2  0.073728  95.515601   0.613363
# 5    0.358837  0.0010  1.624490       4  0.097483  31.973447  13.576040
# 6    0.758565  0.0001  1.409396       2  0.095324  98.238367   2.966572
# 7    0.282841  0.0001 -0.503811       8  0.040463  54.628206   5.718677
# 8    0.766176  0.0100 -0.934000       8  0.025639  54.166346   1.031603
# 9    0.249018  0.0010 -0.171736       8  0.024620  75.048054   3.909572
# 10   0.868100  0.0001 -0.288717       8  0.017705  73.658816   2.566679
# 11   0.574206  0.0001 -1.118905       2  0.036165  82.904841   1.220267
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(TrainData2, TrainData1.time, test_size=.2, random_state=100)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((320, 13), (320,), (80, 13), (80,))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
from sklearn import linear_model
model = MLPRegressor(hidden_layer_sizes=(1000,1000,200),  activation='relu', solver='lbfgs', alpha=0.001, batch_size='auto',
    learning_rate='constant', learning_rate_init=1, power_t=0.5, max_iter=100, shuffle=True,
    random_state= None, tol=0.0001, verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True,
    early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=10)

model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error
y_pred = model.predict(X_test)
MSE=mean_squared_error(y_test, y_pred)
print(MSE)
# Out:
# 6.09010854134956

# %%
# from sklearn.metrics import mean_squared_error
# import numpy as np
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import PolynomialFeatures
# quadratic_featurizer = PolynomialFeatures(degree=2)
# X_train_quadratic = quadratic_featurizer.fit_transform(X_train)
# X_test_quadratic = quadratic_featurizer.transform(X_test)
# regressor_quadratic = LinearRegression()
# regressor_quadratic.fit(X_train_quadratic, y_train)
# y_pred=regressor_quadratic.predict(X_test_quadratic)
# MSE2=mean_squared_error(y_test, y_pred)
# print(MSE2)

# %%
plt.scatter(f.time, f.time_pred)
plt.xlabel('time')
plt.ylabel('time_pred')
#plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
_ = plt.plot([-100, 100], [-100, 100])

# %%
#f[f.time_pred > f.time*1.7]

# %%
#f.iloc[2]

# %%
#for i in range(0, 400):
    #if f.iat[i,2] > f.iat[i,1]*1.5:
       # print(f.iloc[i])

# %%
from sklearn.metrics import mean_squared_error
y=TrainData['time']
y_pred = result
MSE=mean_squared_error(y, y_pred)
print(MSE)
# Out:
# 5.442962392824195

# %%
result2=[]
#for i in  range(0, 100):
    X2,Y2=make_classification(n_samples = TestData.iat[i,7], n_features= TestData.iat[i,8] , n_classes = TestData.iat[i,9]  , n_clusters_per_class = TestData.iat[i,10] ,n_informative = TestData.iat[i,11], flip_y= TestData.iat[i,12] , scale= TestData.iat[i,13])
    import time
    from sklearn.linear_model import SGDClassifier
    clf = SGDClassifier(penalty = TestData.iat[i,1], l1_ratio = TestData.iat[i,2], alpha = TestData.iat[i,3], max_iter = TestData.iat[i,4], random_state = TestData.iat[i,5], n_jobs = TestData.iat[i,6])
    start = time.time()  
    clf.fit(X2, Y2)
    elapsed = (time.time() - start)
    result2.append(elapsed)
    #print(elapsed)    
print(i,result2)
# Out:
#   File "<ipython-input-63-f62749ce016c>", line 3
#     X2,Y2=make_classification(n_samples = TestData.iat[i,7], n_features= TestData.iat[i,8] , n_classes = TestData.iat[i,9]  , n_clusters_per_class = TestData.iat[i,10] ,n_informative = TestData.iat[i,11], flip_y= TestData.iat[i,12] , scale= TestData.iat[i,13])
#     ^
# IndentationError: unexpected indent

# %%
result2 = [1.5479130744934082, 12.866007804870605, 0.7250831127166748, 1.8606860637664795, 3.2906901836395264, 13.058588981628418, 3.2845141887664795, 1.3367679119110107, 14.92755913734436, 0.5044090747833252, 5.548185110092163, 44.62946581840515, 1.3394689559936523, 33.71467399597168, 0.20279312133789062, 1.026487112045288, 1.2405860424041748, 12.955964803695679, 3.8026669025421143, 2.3502938747406006, 0.3137221336364746, 0.43428969383239746, 1.6306509971618652, 2.134169101715088, 4.276684999465942, 4.708520889282227, 2.5051651000976562, 12.93292498588562, 2.0454261302948, 5.027074098587036, 22.862618923187256, 3.109755039215088, 1.8420600891113281, 7.2019898891448975, 17.56307315826416, 0.9276821613311768, 5.522895812988281, 4.417762041091919, 1.2511298656463623, 2.3121399879455566, 9.612487077713013, 9.295817852020264, 1.6459572315216064, 12.938749074935913, 0.9410393238067627, 1.3829879760742188, 5.046587944030762, 1.1428508758544922, 8.322582006454468, 1.2518441677093506, 0.314450740814209, 32.21792221069336, 0.21136212348937988, 9.374010801315308, 14.488179922103882, 0.27156782150268555, 1.4434211254119873, 1.7580790519714355, 0.5614569187164307, 1.659240961074829, 1.4478869438171387, 6.071429252624512, 0.5732107162475586, 18.647335290908813, 3.405856132507324, 34.529881954193115, 0.8344027996063232, 0.8394360542297363, 9.934409856796265, 1.3309049606323242, 0.3121309280395508, 0.931678295135498, 7.737385988235474, 0.26958298683166504, 9.198926210403442, 5.736102104187012, 3.0898191928863525, 4.823150873184204, 5.868819952011108, 1.4870867729187012, 19.47332191467285, 6.885962963104248, 8.214017152786255, 1.9579129219055176, 0.820418119430542, 5.656725883483887, 14.912424087524414, 0.6375100612640381, 5.318631172180176, 1.648665189743042, 4.298507213592529, 1.2862389087677002, 2.161163806915283, 25.082474946975708, 8.350966691970825, 4.790454864501953, 41.59323763847351, 0.5134122371673584, 0.8294680118560791, 0.10736298561096191]

# %%
#X_re =np.array(result2).reshape(-1,1)
#y_re = model.predict(X_re)

# %%
pd.set_option('display.max_rows', None)
TestData['time_pre']=result2
TestData1 = pd.get_dummies(TestData, columns = ['penalty'])

# %%
TestData2 = TestData1[['l1_ratio' , 'alpha' , 'max_iter'  , 'n_jobs' , 'n_samples' , 'n_features' , 'n_classes' , 'n_clusters_per_class' , 'flip_y' , 'scale', 'time_pre', 'penalty_elasticnet', 'penalty_l1','penalty_l2','penalty_none']]

# %%
import numpy as np
n_samplefeature = TestData2.n_samples*TestData2.n_features
TestData2['nsamplefeature'] =n_samplefeature
TestData2.drop('n_samples',axis=1, inplace=True)
TestData2.drop('n_features',axis=1, inplace=True)
TestData2['n_classes1'] =n_classes1
TestData2.drop('n_classes',axis=1, inplace=True)
TestData2.drop('n_clusters_per_class',axis=1, inplace=True)

# %%
x = TestData2['max_iter']
TestData2['max_iter'] = (x - np.mean(x) )/np.std(x, ddof = 1)
x1 = TestData2['nsamplefeature']
TestData2['nsamplefeature'] = (x1 - np.mean(x1) )/np.std(x1, ddof = 1)
x1 = TestData2['n_classes1']
TestData2['n_classes1'] = (x1 - np.mean(x1) )/np.std(x1, ddof = 1)

# %%
#n_sampley0 = TestData2.n_samples*TestData2.flip_y
#n_sampley   = TestData2.n_samples - n_sampley0
#TestData2['nsampley'] =n_sampley
#TestData2.drop('flip_y',axis=1, inplace=True)
#n_samplefeature = TestData2.n_samples*TestData2.n_features
#TestData2['nsamplefeature'] =n_samplefeature
#TestData2.drop('n_samples',axis=1, inplace=True)
#TestData2.drop('n_features',axis=1, inplace=True)

# %%
#TestData2.drop('flip_y',axis=1, inplace=True)
#TestData2.drop('n_samples',axis=1, inplace=True)
#TestData2.drop('n_features',axis=1, inplace=True)
#TestData2.drop('scale',axis=1, inplace=True)
#TestData2.drop('l1_ratio',axis=1, inplace=True)
#TestData2.drop('max_iter',axis=1, inplace=True)
#TestData2.drop('alpha',axis=1, inplace=True)
# TestData2.drop('n_classes',axis=1, inplace=True)
# TestData2.drop('n_clusters_per_class',axis=1, inplace=True)

# %%
TestData2
# Out:
#     l1_ratio   alpha  max_iter  n_jobs  n_samples  n_features  n_classes  \
# 0   0.690384  0.0010       602       4       1376        1078          3
# 1   0.215088  0.0010       522       4        598        1528         10
# 2   0.217458  0.0010       398      16        553        1008          8
# 3   0.120303  0.0010       439      16       1977        1319          3
# 4   0.458851  0.0100       278       4       1826        1530          7
# 5   0.580799  0.0100       886       4        557        1647          5
# 6   0.893885  0.0010       983       2        300        1744          7
# 7   0.625540  0.0001       634       8        410         826          9
# 8   0.574535  0.0001       958       2        516        1433          5
# 9   0.855400  0.0010       199       1       1609         248          3
# 10  0.350049  0.0001       653       2       1742        1107          6
# 11  0.807638  0.0001       940      -1       1792        1013          8
# ...

# %%
y_re=model.predict(TestData2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-51c97b69a128> in <module>()
# ----> 1 y_re=model.predict(TestData2)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in predict(self, X)
#    1295         """
#    1296         check_is_fitted(self, "coefs_")
# -> 1297         y_pred = self._predict(X)
#    1298         if y_pred.shape[1] == 1:
#    1299             return y_pred.ravel()
#
# /anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py in _predict(self, X)
#     676                                          layer_units[i + 1])))
#     677         # forward propagate
# --> 678         self._forward_pass(activations)
#     679         y_pred = activations[-1]
#     680
#
# ...

# %%
y_re
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-eb0f54e4ced1> in <module>()
# ----> 1 y_re
#
# NameError: name 'y_re' is not defined

# %%
pd.DataFrame({"id":TestData['id'],"time":list(y_re)}).to_csv('/Users/wyx/Desktop/5001prediction.csv', columns=['id','time'],index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-1c975a9db82c> in <module>()
# ----> 1 pd.DataFrame({"id":TestData['id'],"time":list(y_re)}).to_csv('/Users/wyx/Desktop/5001prediction.csv', columns=['id','time'],index=None)
#
# NameError: name 'y_re' is not defined

# %%
for i in range(0, 100):
    if y_re[i] < 0:
        y_re[i] = 0.3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-8265e0d2f84a> in <module>()
#       1 for i in range(0, 100):
# ----> 2     if y_re[i] < 0:
#       3         y_re[i] = 0.3
#
# NameError: name 'y_re' is not defined

# %%
y_re
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-eb0f54e4ced1> in <module>()
# ----> 1 y_re
#
# NameError: name 'y_re' is not defined

# %%
pd.DataFrame({"id":TestData['id'],"time":list(y_re)}).to_csv('/Users/wyx/Desktop/5001prediction.csv', columns=['id','time'],index=None)

# %%
#test
result1=[]
#for i in  range(0, 100):
X1,Y1=make_classification(n_samples = 227, n_features= 1035 , n_classes = 10, n_clusters_per_class =3 ,n_informative = 8, flip_y= 0.0030453539639199723 , scale= 68.05728550738452)
import time
start = time.time()  
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(penalty = None, l1_ratio = 0.6314030966103252, alpha = 0.0001, max_iter = 800, random_state = 150, n_jobs = 4)
clf.fit(X1, Y1)
elapsed = (time.time() - start)
result1.append(elapsed)
#print(elapsed)    
print(result1)
# Out:
# [0.9291868209838867]

# %%
# 1.n_jobs 2.penalty affect the result significant
